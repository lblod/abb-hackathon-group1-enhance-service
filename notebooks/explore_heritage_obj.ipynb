# %%
import requests
import pprint

# %%
def get_heritage_object(heritage_object_id):
    headers = {'Accept': 'application/json'}
    r = requests.get(url='https://inventaris.onroerenderfgoed.be/erfgoedobjecten/' + str(heritage_object_id), headers=headers)
    return r

# %%
pprint.pprint(get_heritage_object(14167).json(), indent=2, sort_dicts=True)
# Out:
# { 'alternatieve_namen': [],
#   'bijlagen': [],
#   'current_state': 75,
#   'dataverantwoordelijke': { 'omschrijving': 'Agentschap Onroerend Erfgoed',
#                              'uri': 'https://id.erfgoed.net/actoren/501'},
#   'disciplines': [{'id': 2, 'naam': 'Bouwkundig'}],
#   'erfgoedwaarde': True,
#   'externe_linken': [ { 'id': 1,
#                         'in_te_vullen_id': '75889',
#                         'omschrijving': 'BALaT KIK-IRPA',
#                         'url': 'http://balat.kikirpa.be/photo.php?objnr=75889'},
#                       { 'id': 2,
#                         'in_te_vullen_id': '354900029',
#                         'omschrijving': "Sint-Catharinakerk, 's-Gravenwezel | "
#                                         'Flickr - Photo Sharing!',
#                         'url': 'https://www.flickr.com/photos/erfgoed/354900029'}],
#   'fysieke_status': {'id': 1, 'naam': 'bewaard'},
#   'id': 14167,
#   'kenmerkgroepen': [ { 'afmetingen': [],
# ...

# %%
pprint.pprint(get_heritage_object(34145).json(), indent=2, sort_dicts=True)
# Out:
# { 'alternatieve_namen': [],
#   'bijlagen': [],
#   'current_state': 75,
#   'dataverantwoordelijke': { 'omschrijving': 'Gemeente Lochristi',
#                              'uri': 'https://id.erfgoed.net/actoren/7445'},
#   'disciplines': [{'id': 2, 'naam': 'Bouwkundig'}],
#   'erfgoedwaarde': False,
#   'externe_linken': [],
#   'fysieke_status': {'id': 3, 'naam': 'niet bewaard'},
#   'id': 34145,
#   'kenmerkgroepen': [ { 'afmetingen': [],
#                         'alle_kenmerkgroepen': False,
#                         'id': 11937,
#                         'naam': 'Kenmerkgroep 1',
#                         'relaties': [ { 'datum': { 'einddatum': { 'granulariteit': { 'id': 1,
#                                                                                      'naam': 'Dag'},
#                                                                   'omschrijving': '1993-12-31'},
#                                                    'periode': True,
# ...

# %%
pprint.pprint(get_heritage_object(31061).json(), indent=2, sort_dicts=True)
# Out:
# { 'alternatieve_namen': [],
#   'bijlagen': [],
#   'current_state': 75,
#   'dataverantwoordelijke': { 'omschrijving': 'Agentschap Onroerend Erfgoed',
#                              'uri': 'https://id.erfgoed.net/actoren/501'},
#   'disciplines': [{'id': 2, 'naam': 'Bouwkundig'}],
#   'erfgoedwaarde': True,
#   'externe_linken': [],
#   'fysieke_status': {'id': 1, 'naam': 'bewaard'},
#   'id': 31061,
#   'kenmerkgroepen': [ { 'afmetingen': [],
#                         'alle_kenmerkgroepen': False,
#                         'id': 95156,
#                         'naam': 'Kenmerkgroep 1',
#                         'relaties': [ { 'datum': { 'einddatum': { 'granulariteit': { 'id': 1,
#                                                                                      'naam': 'Dag'},
#                                                                   'omschrijving': '1989-12-31'},
#                                                    'periode': True,
# ...

# %%
pprint.pprint(get_heritage_object(135025).json(), indent=2, sort_dicts=True)
# Out:
# { 'alternatieve_namen': [],
#   'bijlagen': [],
#   'current_state': 75,
#   'dataverantwoordelijke': { 'omschrijving': 'Agentschap Onroerend Erfgoed',
#                              'uri': 'https://id.erfgoed.net/actoren/501'},
#   'disciplines': [{'id': 3, 'naam': 'Landschappelijk'}],
#   'erfgoedwaarde': True,
#   'externe_linken': [],
#   'fysieke_status': {'id': 1, 'naam': 'bewaard'},
#   'id': 135025,
#   'kenmerkgroepen': [ { 'afmetingen': [],
#                         'alle_kenmerkgroepen': False,
#                         'id': 131168,
#                         'naam': 'Kenmerkgroep 1',
#                         'relaties': [ { 'datum': { 'einddatum': { 'granulariteit': { 'id': 1,
#                                                                                      'naam': 'Dag'},
#                                                                   'omschrijving': '2001-02-28'},
#                                                    'periode': True,
# ...

# %%
pprint.pprint(get_heritage_object(38746).json(), indent=2, sort_dicts=True)
# Out:
# { 'alternatieve_namen': ['Les Buttes Blanches'],
#   'bijlagen': [],
#   'current_state': 75,
#   'dataverantwoordelijke': { 'omschrijving': 'Agentschap Onroerend Erfgoed',
#                              'uri': 'https://id.erfgoed.net/actoren/501'},
#   'disciplines': [{'id': 2, 'naam': 'Bouwkundig'}],
#   'erfgoedwaarde': True,
#   'externe_linken': [],
#   'fysieke_status': {'id': 1, 'naam': 'bewaard'},
#   'id': 38746,
#   'kenmerkgroepen': [ { 'afmetingen': [],
#                         'alle_kenmerkgroepen': False,
#                         'id': 36973,
#                         'naam': 'Kenmerkgroep 1',
#                         'relaties': [ { 'datum': { 'einddatum': { 'granulariteit': { 'id': 1,
#                                                                                      'naam': 'Dag'},
#                                                                   'omschrijving': '1991-12-31'},
#                                                    'periode': True,
# ...
